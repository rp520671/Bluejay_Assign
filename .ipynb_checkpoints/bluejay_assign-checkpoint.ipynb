# %%
import pandas as pd
from datetime import datetime, timedelta

# Function to load the Excel file and perform analysis
def analyze_excel_file(file_path, consecutive_days_threshold=7):
    try:
        # Read the Excel sheet into a DataFrame
        df = pd.read_excel(file_path)

        # Trim column names to remove leading/trailing spaces
        df.columns = df.columns.str.strip()

        # Initialize sets to keep track of printed employees
        consecutive_printed = set()
        short_break_printed = set()
        long_shift_printed = set()

        
        print("1: Worked for 7 consecutive days ::- \n")

        for index, row in df.iterrows():
            employee_name = row['Employee Name']
            position_id = row['Position ID']

            if employee_name in consecutive_printed:
                continue

            # Check for consecutive days worked
            if index > 0 and employee_name == df.at[index - 1, 'Employee Name']:
                consecutive_days = 1
                for i in range(index - 1, -1, -1):
                    if df.at[i, 'Employee Name'] == employee_name:
                        consecutive_days += 1
                    else:
                        break
                if consecutive_days >= consecutive_days_threshold:
                    print(f"Employee: {employee_name}, Position: {position_id}")
                    consecutive_printed.add(employee_name)

   
        print("\n2:  who have less than 10 hours of time between shifts but greater than 1 hour ::-\n")

    
        employee_breaks = {}  # Dictionary to track breaks for each employee

        for index, row in df.iterrows():
            employee_name = row['Employee Name']
            position_id = row['Position ID']

            if employee_name in short_break_printed:
                continue

            if employee_name in employee_breaks:
                last_time_out = employee_breaks[employee_name]
                time_in = row['Time']

                if isinstance(time_in, str) and isinstance(last_time_out, str):
                    time_in = datetime.strptime(time_in, '%m/%d/%Y %I:%M %p')
                    last_time_out = datetime.strptime(last_time_out, '%m/%d/%Y %I:%M %p')

                    time_diff = (time_in - last_time_out).total_seconds() / 3600
                    if 1 < time_diff < 10:
                        print(f"Employee: {employee_name}, Position: {position_id}")
                        short_break_printed.add(employee_name)
                else:
                    time_in = None

            employee_breaks[employee_name] = row['Time Out']


        print("\n3: Who has worked for more than 14 hours in a single shift ::- \n")

        for index, row in df.iterrows():
            employee_name = row['Employee Name']
            position_id = row['Position ID']

            if employee_name in long_shift_printed:
                continue

            # Check for shifts longer than 14 hours
            duration_str = row['Timecard Hours (as Time)']
            if pd.notna(duration_str):
                try:
                    hours, minutes = map(int, duration_str.split(':'))
                    duration = timedelta(hours=hours, minutes=minutes)
                except ValueError:
                    # Handle invalid duration format 
                    duration = None
            else:
                # Handle missing values
                duration = None

            if duration is not None and duration.total_seconds() / 3600 > 14:
                print(f"Employee: {employee_name}, Position: {position_id}")
                long_shift_printed.add(employee_name)

    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred: {str(e)}")

if __name__ == "__main__":

    file_path = 'Assignment_Timecard.xlsx'

    # Call the analyze_excel_file function with the specified consecutive_days_threshold
    analyze_excel_file(file_path, consecutive_days_threshold=7)
# Out:
# 1: Worked for 7 consecutive days ::-
#
# Employee: REsaXiaWE, XAis, Position: WFS000065
# Employee: Sparks, KeWWeMh, Position: WFS000101
# Employee: GaXCes, EXias XEpez, Position: WFS000127
# Employee: CaMaXaWE, CeghaW, Position: WFS000153
# Employee: Arias, FeXipe, Position: WFS000170
# Employee: Merrazas, GriaW, Position: WFS000180
# Employee: GarWes, JAsMiW, Position: WFS000181
# Employee: FeXix, XeEWeX, Position: WFS000183
# Employee: HerCEsiXXE, PedrE, Position: WFS000185
# Employee: Xee, XaCar, Position: WFS000200
# Employee: GaWks, GryaW, Position: WFS000226
# Employee: MAake, CasiaWE, Position: WFS000228
# Employee: SiWgh, MarAWpreeM, Position: WFS000246
# Employee: DiWh, DaA, Position: WFS000268
# Employee: ArEsMigAi, AXexaWder, Position: WFS000306
# Employee: De Xa Cerda, IgWaciE, Position: WFS000318
# Employee: REdrigAez, PedrE, Position: WFS000336
# Employee: MraW, WiXXiaC Ha, Position: WFS000345
# Employee: MAcker, CichaeX, Position: WFS000360
# Employee: CaMXEck, CEhaCCed, Position: WFS000362
# Employee: MaXeGi, ACirCasEAd, Position: WFS000364
# Employee: PayaW, DaWieX, Position: WFS000368
# Employee: ErMiz, AGigaiX, Position: WFS000372
# Employee: ErEpeza, JEvaW, Position: WFS000382
# Employee: VasqAez, AXfredE, Position: WFS000391
# Employee: SavaWg, JEhW, Position: WFS000393
# Employee: REdrigAez, XAis, Position: WFS000412
# Employee: EasMCaW, CichaeX, Position: WFS000414
# Employee: SiWgh, CaWpreeM, Position: WFS000418
# Employee: SiWgh, JaspreeM, Position: WFS000424
# Employee: SiWgXeMEW, REger, Position: WFS000426
# Employee: PaXaciE, JEWaMhaW, Position: WFS000434
# Employee: ErEzcE, SaAX, Position: WFS000442
# Employee: CercadE, SaAX, Position: WFS000446
# Employee: CEreira Jr, JEse, Position: WFS000456
# Employee: AXvarez, Edgar, Position: WFS000457
# Employee: PaAXE, KyXe, Position: WFS000460
# Employee: XiWW, JAsMiW, Position: WFS000462
# Employee: CaXdEWadE, AXfEWsE, Position: WFS000463
# Employee: CeWdEza, Erik, Position: WFS000465
# Employee: PerkiWs, MarraWce, Position: WFS000469
# Employee: GAeWdia, JAaW CarXEs, Position: WFS000473
# Employee: ZaCEra, Edward, Position: WFS000477
# Employee: ArevaXE, JEse, Position: WFS000491
# Employee: CErMes, DEAgXas Farid, Position: WFS000495
# Employee: CercadE, CrisMiaW, Position: WFS000496
# Employee: ZaCEra, CigAeX, Position: WFS000499
# Employee: Caxies, MerreXX, Position: WFS000500
# Employee: CcRAWWeX, REWaXd Xee, Position: WFS000501
# Employee: CEMMa, Jessica, Position: WFS000503
# Employee: Rivera AXcaWMar, GrayaW, Position: WFS000507
# Employee: EXivares, FeXCaW, Position: WFS000508
# Employee: ChaCErE, HEXger CarMiWez, Position: WFS000509
# Employee: WiXXiaCs, MyrreXX, Position: WFS000511
# Employee: CaraGiXXa, AWMhEWy, Position: WFS000514
# Employee: GrACfieXd, CErWeXiAs, Position: WFS000515
# Employee: Perez, EdwiW JiCeWez, Position: WFS000517
# Employee: ArrAMia, AXexis ArMArE, Position: WFS000518
# Employee: DiXXard, JEwaWW Cedric, Position: WFS000519
# Employee: SaWchez PaCpXEWa, CrisMiaW AXGerM, Position: WFS000521
# Employee: XEpez WAWez, XAis, Position: WFS000522
# Employee: DeXgadiXXE REdarMe, ChrisMiaW S, Position: WFS000523
# Employee: CeciWa, SiXvesMre Jr, Position: WFS000528
# Employee: FaGiaW CiraWda, JEse, Position: WFS000530
# Employee: HaCiXMEW, DeaWMe DevEW, Position: WFS000536
# Employee: HAWMer, ViWceWM De PaAX, Position: WFS000538
# Employee: AXcEcer, ECar JesAs, Position: WFS000541
# Employee: IWGEAa, JeffersEW, Position: WFS000546
# Employee: CesiWa CEreWE, KeviW FaGiaW, Position: WFS000548
# Employee: HEGGie ErMega, SeGasMiaW CichaeX, Position: WFS000549
# Employee: REdrigAez, GraWdEW AWgeX, Position: WFS000550
# Employee: Diaz GaXvez, RicardE JEsAe, Position: WFS000551
# Employee: EsMrada, JEse FeXix, Position: WFS000552
# Employee: SMrickXaWd, REdWey EAgeWe, Position: WFS000555
# Employee: RAvaXcaGa GaWAeXEs, DaWieX JesAs, Position: WFS000556
# Employee: JerEWiCE CEraXes, CarXEs D, Position: WFS000557
# Employee: DECiWgAez AviWa, CigAeX AWgeX, Position: WFS000569
# Employee: CAevas ZavaXa, JErge XAis, Position: WFS000571
# Employee: XariEs XaWdaverde, XAis ErWesME, Position: WFS000572
# Employee: VaXderraCa CasMiXXE, Escar FaGiaW, Position: WFS000573
# Employee: CiGriaW DeXgadE, EXeWa S, Position: WFS000574
# Employee: SaWchez, ArWAXfE, Position: WFS000577
# Employee: VasqAez, JEhW SeGasMiaW, Position: WFS000578
# Employee: GAMierrez, PedrE CigAeX, Position: WFS000579
# Employee: HerWaWdez SaWchez, AWdrew AWMhEWy, Position: WFS000581
# Employee: De XEs SaWMEs, JEseph XAis, Position: WFS000582
# Employee: ViXXa, AXfredE AieXXE, Position: WFS000583
# Employee: ArCeWMa FXEres, JEWaMhaW, Position: WFS000584
# Employee: RaCEs HerWaWdez, AdieX ECar, Position: WFS000585
# Employee: XariEs, Cesar GiEvaWWi, Position: WFS000587
# Employee: AGeX, WaMhaW REGerM PeWa, Position: WFS000588
# Employee: WgAyeW, RayCEWd, Position: WFS000589
#
#  2:  who have less than 10 hours of time between shifts but greater than 1 hour ::-
#
#
#  3: Who has worked for more than 14 hours in a single shift ::-
#
# Employee: DeXgadiXXE REdarMe, ChrisMiaW S, Position: WFS000523
